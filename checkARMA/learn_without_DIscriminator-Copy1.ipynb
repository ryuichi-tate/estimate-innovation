# %% [markdown]
# ARから作ったデータでやる

# %%
import argparse
import os
path = os.getcwd()
path=path[:path.find('estimate-innovation')+20]
# No = (os.path.basename(__file__))[-4]
No = "0_1" # notebook用
# print('実験No.'+No)
import warnings
warnings.simplefilter('ignore')# 警告を非表示
import numpy as np
np.set_printoptions(precision=4, floatmode='fixed', suppress=True)
import matplotlib.pyplot as plt
from scipy import stats
import math
import sys
sys.path.append(path)
import random
import time
import statsmodels.api as sm
from scipy.stats import norm
import japanize_matplotlib
from scipy.stats import gaussian_kde

import torchvision.transforms as transforms
from torchvision.utils import save_image

import torch.nn as nn
import torch.nn.functional as F
import torch
from torch.autograd import Variable
# 人工データを生成してくれる機械が置いてあるところ
import tsModel
# 学習用のニューラルネットが置いてあるところ
import models
# p-Wasserstein距離の関数
import Wasserstein

# %%
phi_a = [1.0, -0.5, 0.7, -0.4]
phi_b = [0]
p = len(phi_a)
q = len(phi_b)
dataSeed=5
N = 1000
data = tsModel.ARIMA(a=phi_a, b=phi_b, N=N, random_seed=dataSeed, randomness='normal')
inno = tsModel.ARIMA(a=phi_a, b=phi_b, N=N, random_seed=dataSeed, randomness='normal', return_innovation=True)

# %% [markdown]
# ### 非線形ARで同じARMAモデル時系列を推定してちゃんとmseが下がるかどうか
# を確認する
#
# まずは、AR(p)を仮定したモデリングを行う。つまり、中間層は一次元。最初はAIC最小と言われた$\hat p=6$でやる

# %%
hat_p = 6
hat_q = 0

# %%
# 学習する推定モデルの形状や学習方法なんかを決定します
# 学習時のハイパラの決定（入力を受け付ける）
parser = argparse.ArgumentParser()
parser.add_argument("--generator_seed", type=int, default=0, help="generatorのパラメータの初期値のシード")
parser.add_argument("--predictor_seed", type=int, default=0, help="predictorのパラメータの初期値のシード")
parser.add_argument("--batch_size", type=int, default=64, help="batchの大きさ")
parser.add_argument("--training_seed", type=int, default=0, help="訓練データを学習させる順番を決めるシード")
parser.add_argument("--n_epochs", type=int, default=2000, help="学習させる回数")

opt = parser.parse_args(args=[]) # .ipynbの場合はこちらを使用

opt.batch_size=128

# %%
os.makedirs("output-images/p{0}".format(hat_p), exist_ok=True)
os.makedirs("parameters/p{0}".format(hat_p), exist_ok=True)

# %%
import checkGPU
cuda, device = checkGPU.checkGPU()
# Out:
# GPUは使えません。

# %%
import models
torch.manual_seed(opt.generator_seed)
generator = models.Generator(p = p, q=q)

# %%
a= torch.rand([opt.batch_size,1,p+1])# 最初はバッチサイズ
print("input size   :",a.shape)
b = generator(a)
print("output size:",b.shape)
# Out:
# input size   : torch.Size([128, 1, 5])
# output size: torch.Size([128, 2])

# %%
class predictNet(nn.Module):
    def __init__(self, p=7, n_unit1=16, n_unit2=16):
        super(predictNet, self).__init__()
        
        self.fc1 = nn.Linear(p+1, n_unit1)
        self.fc2 = nn.Linear(n_unit1, n_unit2)
        self.fc3 = nn.Linear(n_unit2,1)
        
    def forward(self,x):
        x = self.fc1(x)
        x = F.leaky_relu(x)
        x = self.fc2(x)
        x = F.leaky_relu(x)
        x = self.fc3(x)
        return x

# %%
torch.manual_seed(opt.predictor_seed)
predictor = predictNet(p=hat_p)

# %%
a= torch.rand([opt.batch_size, hat_p+1])# 最初はバッチサイズ
print("input size   :",a.shape)
b = predictor(a)
print("output size:",b.shape)
# Out:
# input size   : torch.Size([128, 7])
# output size: torch.Size([128, 1])

# %%
Data = data.copy()
Data = torch.tensor(Data, dtype=torch.float)
Data=Data.view(1,-1) # 一次元の時系列ならこれで。
trainData = Data[:,:900]
valData = Data[:,900:]

# %%
optimizer_G = torch.optim.Adam(params=generator.parameters(), lr=0.0001 )
optimizer_F = torch.optim.Adam(params=predictor.parameters(), lr=0.0001 )
# optimizer_F = torch.optim.RMSprop(params=predictor.parameters())

# %%
mseLoss = nn.MSELoss()

# %%
# パラメータと学習データをGPUに乗っける
generator.to(device)
predictor.to(device)
trainData = trainData.to(device)
valData = valData.to(device)
mseLoss = mseLoss.to(device)

# %%
# 学習方法の決定？

# %%
def make_XY(x:np.ndarray, p:int):
    x = torch.tensor(x, dtype=torch.float)
    X = [x[i:i+p] for i in range(len(x)-p)]
    Y = [x[i+p] for i in range(len(x)-p)]
    return X, Y

# %%
class DataSet:
    def __init__(self, tsData, hat_p):
        """
        tsData：時系列データ（今回は一次元の時系列を想定）
        hat_p　：想定する次数
        initで入力データと出力データを作成する。
        """
        self.tsData =  torch.tensor(tsData, dtype=torch.float) # torch.tensorに変換
        self.hat_p = hat_p
        self.X, self.Y = make_XY(self.tsData, self.hat_p)
    
    def  __len__(self):
        return len(self.X) # データ数を返す
    
    def __getitem__(self, index):
        return self.X[index], self.Y[index]

# %%
dataset = DataSet(data, hat_p=hat_p)
dataloader = torch.utils.data.DataLoader(dataset, batch_size=opt.batch_size, shuffle=True, drop_last=True)# dataloaderをiterで回すと、毎回入力と出力のペアがlistでくる

# %%
# class withoutDiscriminator:
#     """
#     提案手法
#     """
#     def __init__(self, tsData, hat_p):
#         self.X = 
#         pass
    
#     def fit(self):
#         pass
    
#     def predict(self, x):
#         pass

# %%
# 学習データの使い方のシードを決定
random.seed(a=opt.training_seed)

# ---------
# Fのpretrain
# ---------
n_epoch_pre = 1000
loss_F_pre = []
# Lossの遷移の履歴に学習前の状態のLossを加える
a=0
for X, Y in dataloader:
    input_tensor = torch.cat([torch.zeros([opt.batch_size,1]).to(device), X], axis=1)
    a+=(mseLoss(predictor(input_tensor), Y)).item()
loss_F_pre.append(a/len(dataloader))


    
    
pretrain_param = 'parameters/p{0}/No{1}_predictor_epoch{2}_batchSize{3}_DataSeed{4}.pth'.format(hat_p, No, 0, opt.batch_size, dataSeed )

start=time.time()

for epoch in range(n_epoch_pre):
    epoch_loss = 0
    for X, Y in dataloader:
        input_tensor = torch.cat([torch.randn([opt.batch_size,1]).to(device), X], axis=1)# ランダムな次元を追加
        optimizer_F.zero_grad()
        loss_F = mseLoss(predictor(input_tensor), Y)
        loss_F.backward()
        optimizer_F.step()
        epoch_loss += loss_F.item()
    loss_F_pre.append(epoch_loss/len(dataloader))
    print("epoch：{0}/{1}   loss_F：{2: .4f}   経過時間：{3: .1f}秒".format(epoch+1, n_epoch_pre, round(loss_F_pre[-1], 4), time.time()-start))

torch.save(predictor.state_dict(), pretrain_param)

plt.figure(figsize=(13,6))
plt.title("PredictorのLossの遷移　\n　batchSize:{0}".format(opt.batch_size))
plt.xlabel("epoch")
plt.ylabel("Loss")
plt.plot(loss_F_pre, label="training")
plt.plot(0,loss_F_pre[0], marker='o', markersize=20, color="red")
plt.legend()
plt.savefig("output-images/p{0}/No{1}_preloss_batchSize{3}_DataSeed{4}.png".format(hat_p, No, epoch, opt.batch_size, dataSeed ))
# plt.close()
# Out:
# epoch：1/1000   loss_F： 3.7310   経過時間： 0.0秒
# epoch：2/1000   loss_F： 3.6668   経過時間： 0.0秒
# epoch：3/1000   loss_F： 3.7811   経過時間： 0.1秒
# epoch：4/1000   loss_F： 3.6142   経過時間： 0.1秒
# epoch：5/1000   loss_F： 3.7277   経過時間： 0.1秒
# epoch：6/1000   loss_F： 3.7302   経過時間： 0.1秒
# epoch：7/1000   loss_F： 3.7784   経過時間： 0.2秒
# epoch：8/1000   loss_F： 3.7727   経過時間： 0.2秒
# epoch：9/1000   loss_F： 3.7283   経過時間： 0.2秒
# epoch：10/1000   loss_F： 3.7112   経過時間： 0.2秒
# epoch：11/1000   loss_F： 3.8035   経過時間： 0.2秒
# epoch：12/1000   loss_F： 3.6263   経過時間： 0.3秒
# epoch：13/1000   loss_F： 3.7728   経過時間： 0.3秒
# epoch：14/1000   loss_F： 3.7321   経過時間： 0.3秒
# epoch：15/1000   loss_F： 3.7495   経過時間： 0.3秒
# epoch：16/1000   loss_F： 3.7029   経過時間： 0.3秒
# epoch：17/1000   loss_F： 3.7090   経過時間： 0.4秒
# epoch：18/1000   loss_F： 3.6999   経過時間： 0.4秒
# epoch：19/1000   loss_F： 3.7676   経過時間： 0.4秒
# epoch：20/1000   loss_F： 3.7290   経過時間： 0.4秒
# epoch：21/1000   loss_F： 3.6926   経過時間： 0.5秒
# epoch：22/1000   loss_F： 3.6825   経過時間： 0.5秒
# epoch：23/1000   loss_F： 3.6317   経過時間： 0.5秒
# epoch：24/1000   loss_F： 3.7485   経過時間： 0.5秒
# epoch：25/1000   loss_F： 3.7390   経過時間： 0.5秒
# epoch：26/1000   loss_F： 3.5582   経過時間： 0.6秒
# epoch：27/1000   loss_F： 3.6748   経過時間： 0.6秒
# epoch：28/1000   loss_F： 3.7399   経過時間： 0.6秒
# epoch：29/1000   loss_F： 3.5564   経過時間： 0.6秒
# epoch：30/1000   loss_F： 3.5978   経過時間： 0.6秒
# epoch：31/1000   loss_F： 3.7165   経過時間： 0.7秒
# epoch：32/1000   loss_F： 3.7066   経過時間： 0.7秒
# epoch：33/1000   loss_F： 3.6705   経過時間： 0.7秒
# epoch：34/1000   loss_F： 3.7898   経過時間： 0.7秒
# epoch：35/1000   loss_F： 3.6524   経過時間： 0.8秒
# epoch：36/1000   loss_F： 3.7279   経過時間： 0.8秒
# epoch：37/1000   loss_F： 3.6579   経過時間： 0.8秒
# epoch：38/1000   loss_F： 3.6251   経過時間： 0.8秒
# epoch：39/1000   loss_F： 3.7828   経過時間： 0.8秒
# epoch：40/1000   loss_F： 3.7621   経過時間： 0.8秒
# epoch：41/1000   loss_F： 3.7245   経過時間： 0.9秒
# epoch：42/1000   loss_F： 3.7382   経過時間： 0.9秒
# epoch：43/1000   loss_F： 3.6947   経過時間： 0.9秒
# epoch：44/1000   loss_F： 3.7891   経過時間： 0.9秒
# epoch：45/1000   loss_F： 3.7813   経過時間： 0.9秒
# epoch：46/1000   loss_F： 3.6666   経過時間： 1.0秒
# epoch：47/1000   loss_F： 3.7016   経過時間： 1.0秒
# epoch：48/1000   loss_F： 3.6064   経過時間： 1.0秒
# epoch：49/1000   loss_F： 3.7867   経過時間： 1.0秒
# epoch：50/1000   loss_F： 3.7613   経過時間： 1.0秒
# epoch：51/1000   loss_F： 3.7884   経過時間： 1.0秒
# epoch：52/1000   loss_F： 3.7143   経過時間： 1.1秒
# epoch：53/1000   loss_F： 3.6848   経過時間： 1.1秒
# epoch：54/1000   loss_F： 3.6385   経過時間： 1.1秒
# epoch：55/1000   loss_F： 3.6343   経過時間： 1.1秒
# epoch：56/1000   loss_F： 3.6952   経過時間： 1.1秒
# epoch：57/1000   loss_F： 3.6455   経過時間： 1.2秒
# epoch：58/1000   loss_F： 3.6916   経過時間： 1.2秒
# epoch：59/1000   loss_F： 3.7839   経過時間： 1.2秒
# epoch：60/1000   loss_F： 3.6838   経過時間： 1.2秒
# epoch：61/1000   loss_F： 3.6964   経過時間： 1.2秒
# epoch：62/1000   loss_F： 3.7061   経過時間： 1.3秒
# epoch：63/1000   loss_F： 3.6594   経過時間： 1.3秒
# epoch：64/1000   loss_F： 3.6853   経過時間： 1.3秒
# epoch：65/1000   loss_F： 3.6588   経過時間： 1.3秒
# epoch：66/1000   loss_F： 3.6595   経過時間： 1.3秒
# epoch：67/1000   loss_F： 3.7634   経過時間： 1.4秒
# epoch：68/1000   loss_F： 3.7772   経過時間： 1.4秒
# epoch：69/1000   loss_F： 3.7476   経過時間： 1.4秒
# epoch：70/1000   loss_F： 3.7657   経過時間： 1.4秒
# epoch：71/1000   loss_F： 3.7073   経過時間： 1.5秒
# epoch：72/1000   loss_F： 3.7190   経過時間： 1.5秒
# epoch：73/1000   loss_F： 3.7612   経過時間： 1.5秒
# epoch：74/1000   loss_F： 3.7748   経過時間： 1.5秒
# epoch：75/1000   loss_F： 3.7609   経過時間： 1.5秒
# epoch：76/1000   loss_F： 3.6627   経過時間： 1.6秒
# epoch：77/1000   loss_F： 3.6386   経過時間： 1.6秒
# epoch：78/1000   loss_F： 3.7492   経過時間： 1.6秒
# epoch：79/1000   loss_F： 3.6935   経過時間： 1.6秒
# epoch：80/1000   loss_F： 3.7690   経過時間： 1.6秒
# epoch：81/1000   loss_F： 3.7347   経過時間： 1.6秒
# epoch：82/1000   loss_F： 3.6425   経過時間： 1.7秒
# epoch：83/1000   loss_F： 3.7954   経過時間： 1.7秒
# epoch：84/1000   loss_F： 3.7054   経過時間： 1.7秒
# epoch：85/1000   loss_F： 3.7075   経過時間： 1.7秒
# epoch：86/1000   loss_F： 3.7099   経過時間： 1.7秒
# epoch：87/1000   loss_F： 3.6569   経過時間： 1.8秒
# epoch：88/1000   loss_F： 3.7107   経過時間： 1.8秒
# epoch：89/1000   loss_F： 3.6521   経過時間： 1.8秒
# epoch：90/1000   loss_F： 3.6043   経過時間： 1.8秒
# epoch：91/1000   loss_F： 3.6993   経過時間： 1.8秒
# epoch：92/1000   loss_F： 3.7542   経過時間： 1.9秒
# epoch：93/1000   loss_F： 3.7493   経過時間： 1.9秒
# epoch：94/1000   loss_F： 3.7235   経過時間： 1.9秒
# epoch：95/1000   loss_F： 3.6810   経過時間： 1.9秒
# epoch：96/1000   loss_F： 3.7205   経過時間： 1.9秒
# epoch：97/1000   loss_F： 3.6488   経過時間： 2.0秒
# epoch：98/1000   loss_F： 3.6128   経過時間： 2.0秒
# epoch：99/1000   loss_F： 3.7026   経過時間： 2.0秒
# epoch：100/1000   loss_F： 3.7396   経過時間： 2.0秒
# epoch：101/1000   loss_F： 3.6621   経過時間： 2.0秒
# epoch：102/1000   loss_F： 3.6785   経過時間： 2.0秒
# epoch：103/1000   loss_F： 3.7075   経過時間： 2.1秒
# epoch：104/1000   loss_F： 3.6604   経過時間： 2.1秒
# epoch：105/1000   loss_F： 3.5869   経過時間： 2.1秒
# epoch：106/1000   loss_F： 3.6643   経過時間： 2.1秒
# epoch：107/1000   loss_F： 3.6883   経過時間： 2.1秒
# epoch：108/1000   loss_F： 3.6447   経過時間： 2.2秒
# epoch：109/1000   loss_F： 3.6996   経過時間： 2.2秒
# epoch：110/1000   loss_F： 3.6239   経過時間： 2.2秒
# epoch：111/1000   loss_F： 3.7144   経過時間： 2.2秒
# epoch：112/1000   loss_F： 3.7181   経過時間： 2.3秒
# epoch：113/1000   loss_F： 3.6627   経過時間： 2.3秒
# epoch：114/1000   loss_F： 3.7705   経過時間： 2.3秒
# epoch：115/1000   loss_F： 3.6797   経過時間： 2.3秒
# epoch：116/1000   loss_F： 3.7589   経過時間： 2.3秒
# epoch：117/1000   loss_F： 3.6456   経過時間： 2.4秒
# epoch：118/1000   loss_F： 3.7329   経過時間： 2.4秒
# epoch：119/1000   loss_F： 3.6997   経過時間： 2.4秒
# epoch：120/1000   loss_F： 3.7147   経過時間： 2.4秒
# epoch：121/1000   loss_F： 3.8282   経過時間： 2.4秒
# epoch：122/1000   loss_F： 3.7437   経過時間： 2.5秒
# epoch：123/1000   loss_F： 3.7626   経過時間： 2.5秒
# epoch：124/1000   loss_F： 3.6101   経過時間： 2.5秒
# epoch：125/1000   loss_F： 3.7759   経過時間： 2.5秒
# epoch：126/1000   loss_F： 3.7903   経過時間： 2.6秒
# epoch：127/1000   loss_F： 3.6366   経過時間： 2.6秒
# epoch：128/1000   loss_F： 3.6404   経過時間： 2.7秒
# epoch：129/1000   loss_F： 3.7841   経過時間： 2.7秒
# epoch：130/1000   loss_F： 3.6021   経過時間： 2.7秒
# epoch：131/1000   loss_F： 3.5923   経過時間： 2.7秒
# epoch：132/1000   loss_F： 3.5499   経過時間： 2.7秒
# epoch：133/1000   loss_F： 3.6822   経過時間： 2.8秒
# epoch：134/1000   loss_F： 3.6385   経過時間： 2.8秒
# epoch：135/1000   loss_F： 3.7042   経過時間： 2.8秒
# epoch：136/1000   loss_F： 3.6894   経過時間： 2.8秒
# epoch：137/1000   loss_F： 3.6797   経過時間： 2.8秒
# epoch：138/1000   loss_F： 3.6977   経過時間： 2.9秒
# epoch：139/1000   loss_F： 3.7253   経過時間： 2.9秒
# epoch：140/1000   loss_F： 3.7408   経過時間： 2.9秒
# epoch：141/1000   loss_F： 3.7141   経過時間： 2.9秒
# epoch：142/1000   loss_F： 3.6876   経過時間： 2.9秒
# epoch：143/1000   loss_F： 3.4631   経過時間： 3.0秒
# epoch：144/1000   loss_F： 3.6400   経過時間： 3.0秒
# epoch：145/1000   loss_F： 3.7232   経過時間： 3.0秒
# epoch：146/1000   loss_F： 3.7157   経過時間： 3.0秒
# epoch：147/1000   loss_F： 3.6554   経過時間： 3.0秒
# epoch：148/1000   loss_F： 3.6282   経過時間： 3.1秒
# epoch：149/1000   loss_F： 3.6766   経過時間： 3.1秒
# epoch：150/1000   loss_F： 3.7654   経過時間： 3.1秒
# epoch：151/1000   loss_F： 3.6864   経過時間： 3.1秒
# epoch：152/1000   loss_F： 3.6186   経過時間： 3.1秒
# epoch：153/1000   loss_F： 3.6004   経過時間： 3.2秒
# epoch：154/1000   loss_F： 3.7471   経過時間： 3.2秒
# epoch：155/1000   loss_F： 3.6516   経過時間： 3.2秒
# epoch：156/1000   loss_F： 3.5962   経過時間： 3.2秒
# epoch：157/1000   loss_F： 3.5731   経過時間： 3.2秒
# epoch：158/1000   loss_F： 3.7206   経過時間： 3.3秒
# epoch：159/1000   loss_F： 3.6765   経過時間： 3.3秒
# epoch：160/1000   loss_F： 3.7752   経過時間： 3.3秒
# epoch：161/1000   loss_F： 3.6525   経過時間： 3.3秒
# epoch：162/1000   loss_F： 3.7988   経過時間： 3.4秒
# epoch：163/1000   loss_F： 3.7193   経過時間： 3.4秒
# epoch：164/1000   loss_F： 3.6546   経過時間： 3.4秒
# epoch：165/1000   loss_F： 3.7114   経過時間： 3.4秒
# epoch：166/1000   loss_F： 3.6408   経過時間： 3.4秒
# epoch：167/1000   loss_F： 3.6965   経過時間： 3.5秒
# epoch：168/1000   loss_F： 3.7075   経過時間： 3.5秒
# epoch：169/1000   loss_F： 3.6886   経過時間： 3.5秒
# epoch：170/1000   loss_F： 3.7447   経過時間： 3.5秒
# epoch：171/1000   loss_F： 3.6932   経過時間： 3.5秒
# epoch：172/1000   loss_F： 3.6722   経過時間： 3.6秒
# epoch：173/1000   loss_F： 3.7425   経過時間： 3.6秒
# epoch：174/1000   loss_F： 3.7597   経過時間： 3.6秒
# epoch：175/1000   loss_F： 3.7054   経過時間： 3.6秒
# epoch：176/1000   loss_F： 3.7067   経過時間： 3.6秒
# epoch：177/1000   loss_F： 3.6884   経過時間： 3.7秒
# epoch：178/1000   loss_F： 3.6385   経過時間： 3.7秒
# epoch：179/1000   loss_F： 3.7240   経過時間： 3.7秒
# epoch：180/1000   loss_F： 3.6826   経過時間： 3.7秒
# epoch：181/1000   loss_F： 3.7153   経過時間： 3.7秒
# epoch：182/1000   loss_F： 3.6157   経過時間： 3.8秒
# epoch：183/1000   loss_F： 3.6289   経過時間： 3.8秒
# epoch：184/1000   loss_F： 3.7377   経過時間： 3.8秒
# epoch：185/1000   loss_F： 3.8243   経過時間： 3.8秒
# epoch：186/1000   loss_F： 3.7010   経過時間： 3.9秒
# epoch：187/1000   loss_F： 3.7192   経過時間： 3.9秒
# epoch：188/1000   loss_F： 3.6812   経過時間： 3.9秒
# epoch：189/1000   loss_F： 3.7245   経過時間： 3.9秒
# epoch：190/1000   loss_F： 3.5497   経過時間： 3.9秒
# epoch：191/1000   loss_F： 3.6525   経過時間： 4.0秒
# epoch：192/1000   loss_F： 3.6695   経過時間： 4.0秒
# epoch：193/1000   loss_F： 3.6505   経過時間： 4.0秒
# epoch：194/1000   loss_F： 3.7716   経過時間： 4.0秒
# epoch：195/1000   loss_F： 3.6986   経過時間： 4.1秒
# epoch：196/1000   loss_F： 3.6975   経過時間： 4.1秒
# epoch：197/1000   loss_F： 3.7368   経過時間： 4.1秒
# epoch：198/1000   loss_F： 3.6997   経過時間： 4.1秒
# epoch：199/1000   loss_F： 3.6946   経過時間： 4.1秒
# epoch：200/1000   loss_F： 3.5852   経過時間： 4.2秒
# epoch：201/1000   loss_F： 3.7183   経過時間： 4.2秒
# epoch：202/1000   loss_F： 3.6990   経過時間： 4.2秒
# epoch：203/1000   loss_F： 3.7187   経過時間： 4.2秒
# epoch：204/1000   loss_F： 3.7276   経過時間： 4.2秒
# epoch：205/1000   loss_F： 3.7592   経過時間： 4.3秒
# epoch：206/1000   loss_F： 3.6647   経過時間： 4.3秒
# epoch：207/1000   loss_F： 3.6823   経過時間： 4.3秒
# epoch：208/1000   loss_F： 3.7475   経過時間： 4.3秒
# epoch：209/1000   loss_F： 3.7158   経過時間： 4.4秒
# epoch：210/1000   loss_F： 3.7297   経過時間： 4.4秒
# epoch：211/1000   loss_F： 3.7476   経過時間： 4.4秒
# epoch：212/1000   loss_F： 3.6586   経過時間： 4.4秒
# epoch：213/1000   loss_F： 3.7175   経過時間： 4.4秒
# epoch：214/1000   loss_F： 3.6664   経過時間： 4.5秒
# epoch：215/1000   loss_F： 3.7355   経過時間： 4.5秒
# epoch：216/1000   loss_F： 3.7117   経過時間： 4.5秒
# epoch：217/1000   loss_F： 3.6597   経過時間： 4.5秒
# epoch：218/1000   loss_F： 3.6964   経過時間： 4.5秒
# epoch：219/1000   loss_F： 3.7472   経過時間： 4.6秒
# epoch：220/1000   loss_F： 3.7356   経過時間： 4.6秒
# epoch：221/1000   loss_F： 3.6418   経過時間： 4.6秒
# epoch：222/1000   loss_F： 3.6879   経過時間： 4.6秒
# epoch：223/1000   loss_F： 3.7341   経過時間： 4.6秒
# epoch：224/1000   loss_F： 3.7343   経過時間： 4.6秒
# epoch：225/1000   loss_F： 3.6339   経過時間： 4.7秒
# epoch：226/1000   loss_F： 3.6577   経過時間： 4.7秒
# epoch：227/1000   loss_F： 3.6616   経過時間： 4.7秒
# epoch：228/1000   loss_F： 3.6312   経過時間： 4.7秒
# epoch：229/1000   loss_F： 3.7257   経過時間： 4.7秒
# epoch：230/1000   loss_F： 3.5996   経過時間： 4.8秒
# epoch：231/1000   loss_F： 3.6251   経過時間： 4.8秒
# epoch：232/1000   loss_F： 3.6465   経過時間： 4.8秒
# epoch：233/1000   loss_F： 3.6274   経過時間： 4.8秒
# epoch：234/1000   loss_F： 3.6928   経過時間： 4.8秒
# epoch：235/1000   loss_F： 3.6984   経過時間： 4.9秒
# epoch：236/1000   loss_F： 3.6831   経過時間： 4.9秒
# epoch：237/1000   loss_F： 3.7272   経過時間： 4.9秒
# epoch：238/1000   loss_F： 3.7047   経過時間： 4.9秒
# epoch：239/1000   loss_F： 3.6805   経過時間： 4.9秒
# epoch：240/1000   loss_F： 3.5998   経過時間： 5.0秒
# epoch：241/1000   loss_F： 3.5561   経過時間： 5.0秒
# epoch：242/1000   loss_F： 3.7180   経過時間： 5.0秒
# epoch：243/1000   loss_F： 3.7142   経過時間： 5.0秒
# epoch：244/1000   loss_F： 3.6801   経過時間： 5.0秒
# epoch：245/1000   loss_F： 3.7674   経過時間： 5.1秒
# epoch：246/1000   loss_F： 3.6864   経過時間： 5.1秒
# epoch：247/1000   loss_F： 3.5823   経過時間： 5.1秒
# epoch：248/1000   loss_F： 3.6433   経過時間： 5.1秒
# epoch：249/1000   loss_F： 3.6354   経過時間： 5.1秒
# epoch：250/1000   loss_F： 3.5310   経過時間： 5.2秒
# epoch：251/1000   loss_F： 3.7329   経過時間： 5.2秒
# epoch：252/1000   loss_F： 3.6492   経過時間： 5.2秒
# epoch：253/1000   loss_F： 3.7010   経過時間： 5.2秒
# epoch：254/1000   loss_F： 3.6646   経過時間： 5.2秒
# epoch：255/1000   loss_F： 3.7670   経過時間： 5.3秒
# epoch：256/1000   loss_F： 3.6627   経過時間： 5.3秒
# epoch：257/1000   loss_F： 3.7084   経過時間： 5.3秒
# epoch：258/1000   loss_F： 3.6392   経過時間： 5.3秒
# epoch：259/1000   loss_F： 3.6237   経過時間： 5.4秒
# epoch：260/1000   loss_F： 3.7393   経過時間： 5.4秒
# epoch：261/1000   loss_F： 3.6580   経過時間： 5.4秒
# epoch：262/1000   loss_F： 3.6080   経過時間： 5.4秒
# epoch：263/1000   loss_F： 3.7364   経過時間： 5.4秒
# epoch：264/1000   loss_F： 3.6825   経過時間： 5.5秒
# epoch：265/1000   loss_F： 3.6760   経過時間： 5.5秒
# epoch：266/1000   loss_F： 3.5510   経過時間： 5.5秒
# epoch：267/1000   loss_F： 3.7170   経過時間： 5.5秒
# epoch：268/1000   loss_F： 3.5944   経過時間： 5.6秒
# epoch：269/1000   loss_F： 3.6015   経過時間： 5.6秒
# epoch：270/1000   loss_F： 3.6619   経過時間： 5.6秒
# epoch：271/1000   loss_F： 3.6380   経過時間： 5.6秒
# epoch：272/1000   loss_F： 3.6645   経過時間： 5.7秒
# epoch：273/1000   loss_F： 3.6981   経過時間： 5.7秒
# epoch：274/1000   loss_F： 3.7458   経過時間： 5.7秒
# epoch：275/1000   loss_F： 3.6885   経過時間： 5.7秒
# epoch：276/1000   loss_F： 3.6603   経過時間： 5.7秒
# epoch：277/1000   loss_F： 3.7131   経過時間： 5.8秒
# epoch：278/1000   loss_F： 3.7036   経過時間： 5.8秒
# epoch：279/1000   loss_F： 3.6927   経過時間： 5.8秒
# epoch：280/1000   loss_F： 3.7581   経過時間： 5.8秒
# epoch：281/1000   loss_F： 3.7045   経過時間： 5.9秒
# epoch：282/1000   loss_F： 3.7591   経過時間： 5.9秒
# epoch：283/1000   loss_F： 3.6600   経過時間： 5.9秒
# epoch：284/1000   loss_F： 3.7152   経過時間： 5.9秒
# epoch：285/1000   loss_F： 3.7188   経過時間： 5.9秒
# epoch：286/1000   loss_F： 3.6856   経過時間： 6.0秒
# epoch：287/1000   loss_F： 3.7019   経過時間： 6.0秒
# epoch：288/1000   loss_F： 3.6631   経過時間： 6.0秒
# epoch：289/1000   loss_F： 3.7035   経過時間： 6.0秒
# epoch：290/1000   loss_F： 3.7467   経過時間： 6.0秒
# epoch：291/1000   loss_F： 3.7847   経過時間： 6.0秒
# epoch：292/1000   loss_F： 3.7471   経過時間： 6.1秒
# epoch：293/1000   loss_F： 3.6645   経過時間： 6.1秒
# epoch：294/1000   loss_F： 3.7593   経過時間： 6.1秒
# epoch：295/1000   loss_F： 3.6641   経過時間： 6.1秒
# epoch：296/1000   loss_F： 3.7868   経過時間： 6.2秒
# epoch：297/1000   loss_F： 3.6892   経過時間： 6.2秒
# epoch：298/1000   loss_F： 3.6895   経過時間： 6.2秒
# epoch：299/1000   loss_F： 3.6823   経過時間： 6.2秒
# epoch：300/1000   loss_F： 3.6575   経過時間： 6.2秒
# epoch：301/1000   loss_F： 3.6723   経過時間： 6.3秒
# epoch：302/1000   loss_F： 3.6874   経過時間： 6.3秒
# epoch：303/1000   loss_F： 3.7350   経過時間： 6.3秒
# epoch：304/1000   loss_F： 3.6650   経過時間： 6.3秒
# epoch：305/1000   loss_F： 3.7107   経過時間： 6.3秒
# epoch：306/1000   loss_F： 3.7173   経過時間： 6.4秒
# epoch：307/1000   loss_F： 3.7261   経過時間： 6.4秒
# epoch：308/1000   loss_F： 3.6965   経過時間： 6.4秒
# epoch：309/1000   loss_F： 3.7456   経過時間： 6.4秒
# epoch：310/1000   loss_F： 3.6885   経過時間： 6.4秒
# epoch：311/1000   loss_F： 3.6777   経過時間： 6.5秒
# epoch：312/1000   loss_F： 3.7649   経過時間： 6.5秒
# epoch：313/1000   loss_F： 3.6104   経過時間： 6.5秒
# epoch：314/1000   loss_F： 3.7542   経過時間： 6.5秒
# epoch：315/1000   loss_F： 3.6135   経過時間： 6.5秒
# epoch：316/1000   loss_F： 3.6940   経過時間： 6.6秒
# epoch：317/1000   loss_F： 3.6797   経過時間： 6.6秒
# epoch：318/1000   loss_F： 3.7053   経過時間： 6.6秒
# epoch：319/1000   loss_F： 3.6786   経過時間： 6.6秒
# epoch：320/1000   loss_F： 3.7280   経過時間： 6.6秒
# epoch：321/1000   loss_F： 3.6408   経過時間： 6.7秒
# epoch：322/1000   loss_F： 3.6192   経過時間： 6.7秒
# epoch：323/1000   loss_F： 3.6241   経過時間： 6.7秒
# epoch：324/1000   loss_F： 3.6088   経過時間： 6.7秒
# epoch：325/1000   loss_F： 3.6446   経過時間： 6.8秒
# epoch：326/1000   loss_F： 3.6848   経過時間： 6.8秒
# epoch：327/1000   loss_F： 3.6778   経過時間： 6.8秒
# epoch：328/1000   loss_F： 3.6780   経過時間： 6.8秒
# epoch：329/1000   loss_F： 3.7243   経過時間： 6.8秒
# epoch：330/1000   loss_F： 3.6375   経過時間： 6.9秒
# epoch：331/1000   loss_F： 3.6188   経過時間： 6.9秒
# epoch：332/1000   loss_F： 3.6443   経過時間： 6.9秒
# epoch：333/1000   loss_F： 3.6859   経過時間： 6.9秒
# epoch：334/1000   loss_F： 3.7229   経過時間： 6.9秒
# epoch：335/1000   loss_F： 3.6433   経過時間： 7.0秒
# epoch：336/1000   loss_F： 3.6740   経過時間： 7.0秒
# epoch：337/1000   loss_F： 3.6548   経過時間： 7.0秒
# epoch：338/1000   loss_F： 3.7196   経過時間： 7.0秒
# epoch：339/1000   loss_F： 3.7688   経過時間： 7.0秒
# epoch：340/1000   loss_F： 3.7232   経過時間： 7.1秒
# epoch：341/1000   loss_F： 3.6914   経過時間： 7.1秒
# epoch：342/1000   loss_F： 3.6983   経過時間： 7.1秒
# epoch：343/1000   loss_F： 3.6286   経過時間： 7.1秒
# epoch：344/1000   loss_F： 3.6953   経過時間： 7.2秒
# epoch：345/1000   loss_F： 3.6918   経過時間： 7.2秒
# epoch：346/1000   loss_F： 3.6378   経過時間： 7.2秒
# epoch：347/1000   loss_F： 3.7136   経過時間： 7.2秒
# epoch：348/1000   loss_F： 3.7875   経過時間： 7.2秒
# epoch：349/1000   loss_F： 3.7271   経過時間： 7.3秒
# epoch：350/1000   loss_F： 3.6586   経過時間： 7.3秒
# epoch：351/1000   loss_F： 3.6354   経過時間： 7.3秒
# epoch：352/1000   loss_F： 3.6613   経過時間： 7.3秒
# epoch：353/1000   loss_F： 3.6648   経過時間： 7.3秒
# epoch：354/1000   loss_F： 3.7080   経過時間： 7.4秒
# epoch：355/1000   loss_F： 3.7107   経過時間： 7.4秒
# epoch：356/1000   loss_F： 3.6295   経過時間： 7.4秒
# epoch：357/1000   loss_F： 3.7455   経過時間： 7.4秒
# epoch：358/1000   loss_F： 3.6888   経過時間： 7.4秒
# epoch：359/1000   loss_F： 3.6989   経過時間： 7.5秒
# epoch：360/1000   loss_F： 3.6834   経過時間： 7.5秒
# epoch：361/1000   loss_F： 3.7083   経過時間： 7.5秒
# epoch：362/1000   loss_F： 3.7244   経過時間： 7.5秒
# epoch：363/1000   loss_F： 3.6768   経過時間： 7.5秒
# epoch：364/1000   loss_F： 3.7589   経過時間： 7.6秒
# epoch：365/1000   loss_F： 3.7797   経過時間： 7.6秒
# epoch：366/1000   loss_F： 3.6313   経過時間： 7.6秒
# epoch：367/1000   loss_F： 3.7446   経過時間： 7.6秒
# epoch：368/1000   loss_F： 3.5395   経過時間： 7.6秒
# epoch：369/1000   loss_F： 3.6296   経過時間： 7.7秒
# epoch：370/1000   loss_F： 3.7226   経過時間： 7.7秒
# epoch：371/1000   loss_F： 3.6596   経過時間： 7.7秒
# epoch：372/1000   loss_F： 3.7063   経過時間： 7.7秒
# epoch：373/1000   loss_F： 3.7060   経過時間： 7.8秒
# epoch：374/1000   loss_F： 3.7139   経過時間： 7.8秒
# epoch：375/1000   loss_F： 3.6309   経過時間： 7.8秒
# epoch：376/1000   loss_F： 3.6675   経過時間： 7.8秒
# epoch：377/1000   loss_F： 3.7265   経過時間： 7.8秒
# epoch：378/1000   loss_F： 3.7269   経過時間： 7.9秒
# epoch：379/1000   loss_F： 3.7300   経過時間： 7.9秒
# epoch：380/1000   loss_F： 3.7302   経過時間： 7.9秒
# epoch：381/1000   loss_F： 3.7665   経過時間： 7.9秒
# epoch：382/1000   loss_F： 3.6712   経過時間： 7.9秒
# epoch：383/1000   loss_F： 3.7141   経過時間： 8.0秒
# epoch：384/1000   loss_F： 3.6979   経過時間： 8.0秒
# epoch：385/1000   loss_F： 3.7752   経過時間： 8.0秒
# epoch：386/1000   loss_F： 3.6819   経過時間： 8.0秒
# epoch：387/1000   loss_F： 3.6676   経過時間： 8.0秒
# epoch：388/1000   loss_F： 3.6750   経過時間： 8.1秒
# epoch：389/1000   loss_F： 3.7003   経過時間： 8.1秒
# epoch：390/1000   loss_F： 3.8172   経過時間： 8.1秒
# epoch：391/1000   loss_F： 3.5467   経過時間： 8.1秒
# epoch：392/1000   loss_F： 3.7546   経過時間： 8.1秒
# epoch：393/1000   loss_F： 3.7584   経過時間： 8.2秒
# epoch：394/1000   loss_F： 3.8064   経過時間： 8.2秒
# epoch：395/1000   loss_F： 3.6801   経過時間： 8.2秒
# epoch：396/1000   loss_F： 3.5958   経過時間： 8.2秒
# epoch：397/1000   loss_F： 3.7799   経過時間： 8.2秒
# epoch：398/1000   loss_F： 3.7091   経過時間： 8.3秒
# epoch：399/1000   loss_F： 3.7263   経過時間： 8.3秒
# epoch：400/1000   loss_F： 3.7578   経過時間： 8.3秒
# epoch：401/1000   loss_F： 3.7092   経過時間： 8.3秒
# epoch：402/1000   loss_F： 3.7154   経過時間： 8.4秒
# epoch：403/1000   loss_F： 3.7927   経過時間： 8.4秒
# epoch：404/1000   loss_F： 3.7134   経過時間： 8.4秒
# epoch：405/1000   loss_F： 3.6140   経過時間： 8.4秒
# epoch：406/1000   loss_F： 3.7216   経過時間： 8.4秒
# epoch：407/1000   loss_F： 3.6842   経過時間： 8.5秒
# epoch：408/1000   loss_F： 3.7621   経過時間： 8.5秒
# epoch：409/1000   loss_F： 3.5934   経過時間： 8.5秒
# epoch：410/1000   loss_F： 3.6493   経過時間： 8.5秒
# epoch：411/1000   loss_F： 3.6709   経過時間： 8.5秒
# epoch：412/1000   loss_F： 3.6417   経過時間： 8.6秒
# epoch：413/1000   loss_F： 3.7298   経過時間： 8.6秒
# epoch：414/1000   loss_F： 3.5994   経過時間： 8.6秒
# epoch：415/1000   loss_F： 3.6692   経過時間： 8.6秒
# epoch：416/1000   loss_F： 3.7169   経過時間： 8.6秒
# epoch：417/1000   loss_F： 3.7270   経過時間： 8.7秒
# epoch：418/1000   loss_F： 3.7785   経過時間： 8.7秒
# epoch：419/1000   loss_F： 3.6691   経過時間： 8.7秒
# epoch：420/1000   loss_F： 3.7285   経過時間： 8.7秒
# epoch：421/1000   loss_F： 3.6327   経過時間： 8.7秒
# epoch：422/1000   loss_F： 3.6748   経過時間： 8.8秒
# epoch：423/1000   loss_F： 3.6785   経過時間： 8.8秒
# epoch：424/1000   loss_F： 3.7039   経過時間： 8.8秒
# epoch：425/1000   loss_F： 3.6376   経過時間： 8.8秒
# epoch：426/1000   loss_F： 3.6749   経過時間： 8.8秒
# epoch：427/1000   loss_F： 3.6715   経過時間： 8.8秒
# epoch：428/1000   loss_F： 3.7007   経過時間： 8.9秒
# epoch：429/1000   loss_F： 3.6110   経過時間： 8.9秒
# epoch：430/1000   loss_F： 3.8172   経過時間： 8.9秒
# epoch：431/1000   loss_F： 3.7044   経過時間： 8.9秒
# epoch：432/1000   loss_F： 3.6500   経過時間： 8.9秒
# epoch：433/1000   loss_F： 3.6671   経過時間： 9.0秒
# epoch：434/1000   loss_F： 3.6581   経過時間： 9.0秒
# epoch：435/1000   loss_F： 3.7216   経過時間： 9.0秒
# epoch：436/1000   loss_F： 3.7272   経過時間： 9.0秒
# epoch：437/1000   loss_F： 3.6892   経過時間： 9.0秒
# epoch：438/1000   loss_F： 3.6337   経過時間： 9.1秒
# epoch：439/1000   loss_F： 3.6155   経過時間： 9.1秒
# epoch：440/1000   loss_F： 3.6620   経過時間： 9.1秒
# epoch：441/1000   loss_F： 3.8319   経過時間： 9.1秒
# epoch：442/1000   loss_F： 3.7609   経過時間： 9.1秒
# epoch：443/1000   loss_F： 3.7622   経過時間： 9.2秒
# epoch：444/1000   loss_F： 3.7214   経過時間： 9.2秒
# epoch：445/1000   loss_F： 3.5950   経過時間： 9.2秒
# epoch：446/1000   loss_F： 3.5805   経過時間： 9.2秒
# epoch：447/1000   loss_F： 3.7379   経過時間： 9.2秒
# epoch：448/1000   loss_F： 3.7957   経過時間： 9.3秒
# epoch：449/1000   loss_F： 3.7357   経過時間： 9.3秒
# epoch：450/1000   loss_F： 3.5209   経過時間： 9.3秒
# epoch：451/1000   loss_F： 3.7418   経過時間： 9.3秒
# epoch：452/1000   loss_F： 3.7034   経過時間： 9.4秒
# epoch：453/1000   loss_F： 3.6079   経過時間： 9.4秒
# epoch：454/1000   loss_F： 3.6893   経過時間： 9.4秒
# epoch：455/1000   loss_F： 3.7926   経過時間： 9.5秒
# epoch：456/1000   loss_F： 3.7425   経過時間： 9.5秒
# epoch：457/1000   loss_F： 3.6899   経過時間： 9.5秒
# epoch：458/1000   loss_F： 3.7042   経過時間： 9.5秒
# epoch：459/1000   loss_F： 3.7133   経過時間： 9.5秒
# epoch：460/1000   loss_F： 3.7254   経過時間： 9.6秒
# epoch：461/1000   loss_F： 3.7059   経過時間： 9.6秒
# epoch：462/1000   loss_F： 3.5419   経過時間： 9.6秒
# epoch：463/1000   loss_F： 3.6395   経過時間： 9.6秒
# epoch：464/1000   loss_F： 3.6777   経過時間： 9.6秒
# epoch：465/1000   loss_F： 3.7673   経過時間： 9.7秒
# epoch：466/1000   loss_F： 3.5826   経過時間： 9.7秒
# epoch：467/1000   loss_F： 3.6473   経過時間： 9.7秒
# epoch：468/1000   loss_F： 3.6859   経過時間： 9.7秒
# epoch：469/1000   loss_F： 3.8293   経過時間： 9.7秒
# epoch：470/1000   loss_F： 3.7021   経過時間： 9.8秒
# epoch：471/1000   loss_F： 3.5811   経過時間： 9.8秒
# epoch：472/1000   loss_F： 3.6249   経過時間： 9.8秒
# epoch：473/1000   loss_F： 3.8127   経過時間： 9.8秒
# epoch：474/1000   loss_F： 3.7709   経過時間： 9.8秒
# epoch：475/1000   loss_F： 3.6184   経過時間： 9.8秒
# epoch：476/1000   loss_F： 3.7909   経過時間： 9.9秒
# epoch：477/1000   loss_F： 3.6532   経過時間： 9.9秒
# epoch：478/1000   loss_F： 3.7847   経過時間： 9.9秒
# epoch：479/1000   loss_F： 3.7130   経過時間： 9.9秒
# epoch：480/1000   loss_F： 3.7297   経過時間： 10.0秒
# epoch：481/1000   loss_F： 3.7027   経過時間： 10.0秒
# epoch：482/1000   loss_F： 3.6802   経過時間： 10.0秒
# epoch：483/1000   loss_F： 3.6536   経過時間： 10.0秒
# epoch：484/1000   loss_F： 3.6895   経過時間： 10.0秒
# epoch：485/1000   loss_F： 3.6854   経過時間： 10.1秒
# epoch：486/1000   loss_F： 3.7061   経過時間： 10.1秒
# epoch：487/1000   loss_F： 3.7286   経過時間： 10.1秒
# epoch：488/1000   loss_F： 3.6503   経過時間： 10.1秒
# epoch：489/1000   loss_F： 3.6907   経過時間： 10.1秒
# epoch：490/1000   loss_F： 3.7051   経過時間： 10.2秒
# epoch：491/1000   loss_F： 3.6708   経過時間： 10.2秒
# epoch：492/1000   loss_F： 3.6476   経過時間： 10.2秒
# epoch：493/1000   loss_F： 3.7038   経過時間： 10.2秒
# epoch：494/1000   loss_F： 3.6139   経過時間： 10.3秒
# epoch：495/1000   loss_F： 3.7326   経過時間： 10.3秒
# epoch：496/1000   loss_F： 3.6319   経過時間： 10.3秒
# epoch：497/1000   loss_F： 3.7451   経過時間： 10.3秒
# epoch：498/1000   loss_F： 3.6992   経過時間： 10.3秒
# epoch：499/1000   loss_F： 3.5992   経過時間： 10.4秒
# epoch：500/1000   loss_F： 3.7325   経過時間： 10.4秒
# epoch：501/1000   loss_F： 3.7498   経過時間： 10.4秒
# epoch：502/1000   loss_F： 3.6688   経過時間： 10.4秒
# epoch：503/1000   loss_F： 3.5950   経過時間： 10.4秒
# epoch：504/1000   loss_F： 3.6248   経過時間： 10.5秒
# epoch：505/1000   loss_F： 3.6240   経過時間： 10.5秒
# epoch：506/1000   loss_F： 3.7527   経過時間： 10.5秒
# epoch：507/1000   loss_F： 3.6931   経過時間： 10.5秒
# epoch：508/1000   loss_F： 3.7237   経過時間： 10.5秒
# epoch：509/1000   loss_F： 3.6789   経過時間： 10.6秒
# epoch：510/1000   loss_F： 3.6737   経過時間： 10.6秒
# epoch：511/1000   loss_F： 3.6957   経過時間： 10.6秒
# epoch：512/1000   loss_F： 3.6125   経過時間： 10.6秒
# epoch：513/1000   loss_F： 3.6626   経過時間： 10.6秒
# epoch：514/1000   loss_F： 3.7384   経過時間： 10.7秒
# epoch：515/1000   loss_F： 3.5281   経過時間： 10.7秒
# epoch：516/1000   loss_F： 3.7139   経過時間： 10.7秒
# epoch：517/1000   loss_F： 3.7248   経過時間： 10.7秒
# epoch：518/1000   loss_F： 3.7056   経過時間： 10.7秒
# epoch：519/1000   loss_F： 3.6871   経過時間： 10.8秒
# epoch：520/1000   loss_F： 3.7017   経過時間： 10.8秒
# epoch：521/1000   loss_F： 3.6582   経過時間： 10.8秒
# epoch：522/1000   loss_F： 3.7063   経過時間： 10.8秒
# epoch：523/1000   loss_F： 3.6262   経過時間： 10.8秒
# epoch：524/1000   loss_F： 3.6381   経過時間： 10.9秒
# epoch：525/1000   loss_F： 3.7309   経過時間： 10.9秒
# epoch：526/1000   loss_F： 3.7163   経過時間： 10.9秒
# epoch：527/1000   loss_F： 3.6527   経過時間： 10.9秒
# epoch：528/1000   loss_F： 3.6518   経過時間： 11.0秒
# epoch：529/1000   loss_F： 3.6207   経過時間： 11.0秒
# epoch：530/1000   loss_F： 3.6917   経過時間： 11.0秒
# epoch：531/1000   loss_F： 3.6810   経過時間： 11.0秒
# epoch：532/1000   loss_F： 3.7627   経過時間： 11.0秒
# epoch：533/1000   loss_F： 3.6986   経過時間： 11.1秒
# epoch：534/1000   loss_F： 3.7328   経過時間： 11.1秒
# epoch：535/1000   loss_F： 3.6646   経過時間： 11.1秒
# epoch：536/1000   loss_F： 3.7595   経過時間： 11.1秒
# epoch：537/1000   loss_F： 3.6480   経過時間： 11.1秒
# epoch：538/1000   loss_F： 3.5399   経過時間： 11.2秒
# epoch：539/1000   loss_F： 3.7921   経過時間： 11.2秒
# epoch：540/1000   loss_F： 3.7485   経過時間： 11.2秒
# epoch：541/1000   loss_F： 3.7031   経過時間： 11.2秒
# epoch：542/1000   loss_F： 3.7055   経過時間： 11.2秒
# epoch：543/1000   loss_F： 3.6793   経過時間： 11.3秒
# epoch：544/1000   loss_F： 3.7055   経過時間： 11.3秒
# epoch：545/1000   loss_F： 3.5464   経過時間： 11.3秒
# epoch：546/1000   loss_F： 3.6825   経過時間： 11.3秒
# epoch：547/1000   loss_F： 3.7535   経過時間： 11.4秒
# epoch：548/1000   loss_F： 3.7388   経過時間： 11.4秒
# epoch：549/1000   loss_F： 3.6633   経過時間： 11.4秒
# epoch：550/1000   loss_F： 3.6636   経過時間： 11.4秒
# epoch：551/1000   loss_F： 3.6063   経過時間： 11.4秒
# epoch：552/1000   loss_F： 3.6324   経過時間： 11.5秒
# epoch：553/1000   loss_F： 3.6773   経過時間： 11.5秒
# epoch：554/1000   loss_F： 3.7069   経過時間： 11.5秒
# epoch：555/1000   loss_F： 3.7561   経過時間： 11.5秒
# epoch：556/1000   loss_F： 3.6793   経過時間： 11.5秒
# epoch：557/1000   loss_F： 3.4935   経過時間： 11.6秒
# epoch：558/1000   loss_F： 3.7031   経過時間： 11.6秒
# epoch：559/1000   loss_F： 3.5753   経過時間： 11.6秒
# epoch：560/1000   loss_F： 3.7184   経過時間： 11.6秒
# epoch：561/1000   loss_F： 3.7630   経過時間： 11.6秒
# epoch：562/1000   loss_F： 3.6998   経過時間： 11.7秒
# epoch：563/1000   loss_F： 3.6686   経過時間： 11.7秒
# epoch：564/1000   loss_F： 3.5638   経過時間： 11.7秒
# epoch：565/1000   loss_F： 3.6726   経過時間： 11.7秒
# epoch：566/1000   loss_F： 3.7409   経過時間： 11.7秒
# epoch：567/1000   loss_F： 3.6739   経過時間： 11.8秒
# epoch：568/1000   loss_F： 3.7697   経過時間： 11.8秒
# epoch：569/1000   loss_F： 3.5622   経過時間： 11.8秒
# epoch：570/1000   loss_F： 3.6639   経過時間： 11.8秒
# epoch：571/1000   loss_F： 3.6381   経過時間： 11.8秒
# epoch：572/1000   loss_F： 3.7000   経過時間： 11.9秒
# epoch：573/1000   loss_F： 3.6763   経過時間： 11.9秒
# epoch：574/1000   loss_F： 3.7173   経過時間： 11.9秒
# epoch：575/1000   loss_F： 3.6269   経過時間： 11.9秒
# epoch：576/1000   loss_F： 3.7644   経過時間： 11.9秒
# epoch：577/1000   loss_F： 3.6929   経過時間： 12.0秒
# epoch：578/1000   loss_F： 3.5568   経過時間： 12.0秒
# epoch：579/1000   loss_F： 3.7260   経過時間： 12.0秒
# epoch：580/1000   loss_F： 3.6539   経過時間： 12.0秒
# epoch：581/1000   loss_F： 3.6913   経過時間： 12.1秒
# epoch：582/1000   loss_F： 3.6583   経過時間： 12.1秒
# epoch：583/1000   loss_F： 3.5494   経過時間： 12.1秒
# epoch：584/1000   loss_F： 3.7260   経過時間： 12.1秒
# epoch：585/1000   loss_F： 3.7755   経過時間： 12.1秒
# epoch：586/1000   loss_F： 3.6537   経過時間： 12.2秒
# epoch：587/1000   loss_F： 3.7052   経過時間： 12.2秒
# epoch：588/1000   loss_F： 3.7303   経過時間： 12.2秒
# epoch：589/1000   loss_F： 3.7209   経過時間： 12.2秒
# epoch：590/1000   loss_F： 3.6356   経過時間： 12.3秒
# epoch：591/1000   loss_F： 3.6489   経過時間： 12.3秒
# epoch：592/1000   loss_F： 3.7329   経過時間： 12.3秒
# epoch：593/1000   loss_F： 3.7490   経過時間： 12.3秒
# epoch：594/1000   loss_F： 3.6660   経過時間： 12.3秒
# epoch：595/1000   loss_F： 3.6896   経過時間： 12.4秒
# epoch：596/1000   loss_F： 3.7077   経過時間： 12.4秒
# epoch：597/1000   loss_F： 3.6483   経過時間： 12.4秒
# epoch：598/1000   loss_F： 3.7259   経過時間： 12.4秒
# epoch：599/1000   loss_F： 3.8216   経過時間： 12.4秒
# epoch：600/1000   loss_F： 3.6863   経過時間： 12.5秒
# epoch：601/1000   loss_F： 3.6408   経過時間： 12.5秒
# epoch：602/1000   loss_F： 3.7749   経過時間： 12.5秒
# epoch：603/1000   loss_F： 3.7666   経過時間： 12.5秒
# epoch：604/1000   loss_F： 3.7276   経過時間： 12.5秒
# epoch：605/1000   loss_F： 3.7033   経過時間： 12.6秒
# epoch：606/1000   loss_F： 3.6749   経過時間： 12.6秒
# epoch：607/1000   loss_F： 3.6367   経過時間： 12.6秒
# epoch：608/1000   loss_F： 3.7014   経過時間： 12.6秒
# epoch：609/1000   loss_F： 3.6266   経過時間： 12.7秒
# epoch：610/1000   loss_F： 3.6679   経過時間： 12.7秒
# epoch：611/1000   loss_F： 3.7623   経過時間： 12.7秒
# epoch：612/1000   loss_F： 3.7746   経過時間： 12.7秒
# epoch：613/1000   loss_F： 3.6971   経過時間： 12.7秒
# epoch：614/1000   loss_F： 3.6921   経過時間： 12.8秒
# epoch：615/1000   loss_F： 3.7642   経過時間： 12.8秒
# epoch：616/1000   loss_F： 3.7261   経過時間： 12.8秒
# epoch：617/1000   loss_F： 3.6899   経過時間： 12.8秒
# epoch：618/1000   loss_F： 3.7010   経過時間： 12.8秒
# epoch：619/1000   loss_F： 3.7349   経過時間： 12.9秒
# epoch：620/1000   loss_F： 3.6670   経過時間： 12.9秒
# epoch：621/1000   loss_F： 3.6822   経過時間： 12.9秒
# epoch：622/1000   loss_F： 3.6882   経過時間： 12.9秒
# epoch：623/1000   loss_F： 3.6645   経過時間： 12.9秒
# epoch：624/1000   loss_F： 3.7005   経過時間： 13.0秒
# epoch：625/1000   loss_F： 3.7261   経過時間： 13.0秒
# epoch：626/1000   loss_F： 3.6824   経過時間： 13.0秒
# epoch：627/1000   loss_F： 3.7804   経過時間： 13.0秒
# epoch：628/1000   loss_F： 3.7615   経過時間： 13.0秒
# epoch：629/1000   loss_F： 3.7177   経過時間： 13.1秒
# epoch：630/1000   loss_F： 3.6591   経過時間： 13.1秒
# epoch：631/1000   loss_F： 3.7053   経過時間： 13.1秒
# epoch：632/1000   loss_F： 3.6325   経過時間： 13.1秒
# epoch：633/1000   loss_F： 3.7568   経過時間： 13.1秒
# epoch：634/1000   loss_F： 3.7257   経過時間： 13.2秒
# epoch：635/1000   loss_F： 3.7597   経過時間： 13.2秒
# epoch：636/1000   loss_F： 3.6924   経過時間： 13.2秒
# epoch：637/1000   loss_F： 3.5953   経過時間： 13.2秒
# epoch：638/1000   loss_F： 3.7721   経過時間： 13.2秒
# epoch：639/1000   loss_F： 3.6693   経過時間： 13.2秒
# epoch：640/1000   loss_F： 3.6394   経過時間： 13.3秒
# epoch：641/1000   loss_F： 3.6871   経過時間： 13.3秒
# epoch：642/1000   loss_F： 3.6052   経過時間： 13.3秒
# epoch：643/1000   loss_F： 3.6780   経過時間： 13.3秒
# epoch：644/1000   loss_F： 3.6322   経過時間： 13.3秒
# epoch：645/1000   loss_F： 3.7042   経過時間： 13.4秒
# epoch：646/1000   loss_F： 3.7106   経過時間： 13.4秒
# epoch：647/1000   loss_F： 3.5852   経過時間： 13.4秒
# epoch：648/1000   loss_F： 3.6959   経過時間： 13.4秒
# epoch：649/1000   loss_F： 3.7386   経過時間： 13.5秒
# epoch：650/1000   loss_F： 3.6442   経過時間： 13.5秒
# epoch：651/1000   loss_F： 3.6909   経過時間： 13.5秒
# epoch：652/1000   loss_F： 3.7399   経過時間： 13.5秒
# epoch：653/1000   loss_F： 3.6128   経過時間： 13.5秒
# epoch：654/1000   loss_F： 3.6037   経過時間： 13.6秒
# epoch：655/1000   loss_F： 3.7265   経過時間： 13.6秒
# epoch：656/1000   loss_F： 3.7302   経過時間： 13.6秒
# epoch：657/1000   loss_F： 3.5918   経過時間： 13.6秒
# epoch：658/1000   loss_F： 3.7250   経過時間： 13.6秒
# epoch：659/1000   loss_F： 3.7205   経過時間： 13.7秒
# epoch：660/1000   loss_F： 3.7149   経過時間： 13.7秒
# epoch：661/1000   loss_F： 3.6169   経過時間： 13.7秒
# epoch：662/1000   loss_F： 3.6633   経過時間： 13.7秒
# epoch：663/1000   loss_F： 3.7648   経過時間： 13.8秒
# epoch：664/1000   loss_F： 3.6190   経過時間： 13.8秒
# epoch：665/1000   loss_F： 3.5636   経過時間： 13.8秒
# epoch：666/1000   loss_F： 3.7603   経過時間： 13.8秒
# epoch：667/1000   loss_F： 3.7039   経過時間： 13.8秒
# epoch：668/1000   loss_F： 3.7548   経過時間： 13.9秒
# epoch：669/1000   loss_F： 3.7505   経過時間： 13.9秒
# epoch：670/1000   loss_F： 3.6394   経過時間： 13.9秒
# epoch：671/1000   loss_F： 3.6179   経過時間： 13.9秒
# epoch：672/1000   loss_F： 3.7016   経過時間： 13.9秒
# epoch：673/1000   loss_F： 3.6542   経過時間： 14.0秒
# epoch：674/1000   loss_F： 3.7150   経過時間： 14.0秒
# epoch：675/1000   loss_F： 3.7224   経過時間： 14.0秒
# epoch：676/1000   loss_F： 3.6862   経過時間： 14.0秒
# epoch：677/1000   loss_F： 3.6200   経過時間： 14.1秒
# epoch：678/1000   loss_F： 3.6832   経過時間： 14.1秒
# epoch：679/1000   loss_F： 3.5931   経過時間： 14.1秒
# epoch：680/1000   loss_F： 3.6322   経過時間： 14.1秒
# epoch：681/1000   loss_F： 3.6761   経過時間： 14.1秒
# epoch：682/1000   loss_F： 3.7668   経過時間： 14.1秒
# epoch：683/1000   loss_F： 3.6147   経過時間： 14.2秒
# epoch：684/1000   loss_F： 3.6802   経過時間： 14.2秒
# epoch：685/1000   loss_F： 3.6570   経過時間： 14.2秒
# epoch：686/1000   loss_F： 3.5781   経過時間： 14.2秒
# epoch：687/1000   loss_F： 3.6642   経過時間： 14.2秒
# epoch：688/1000   loss_F： 3.7167   経過時間： 14.3秒
# epoch：689/1000   loss_F： 3.7103   経過時間： 14.3秒
# epoch：690/1000   loss_F： 3.6597   経過時間： 14.3秒
# epoch：691/1000   loss_F： 3.6588   経過時間： 14.3秒
# epoch：692/1000   loss_F： 3.6416   経過時間： 14.3秒
# epoch：693/1000   loss_F： 3.6562   経過時間： 14.4秒
# epoch：694/1000   loss_F： 3.6296   経過時間： 14.4秒
# epoch：695/1000   loss_F： 3.7496   経過時間： 14.4秒
# epoch：696/1000   loss_F： 3.5972   経過時間： 14.4秒
# epoch：697/1000   loss_F： 3.6538   経過時間： 14.4秒
# epoch：698/1000   loss_F： 3.6611   経過時間： 14.5秒
# epoch：699/1000   loss_F： 3.6544   経過時間： 14.5秒
# epoch：700/1000   loss_F： 3.6948   経過時間： 14.5秒
# epoch：701/1000   loss_F： 3.6942   経過時間： 14.5秒
# epoch：702/1000   loss_F： 3.6884   経過時間： 14.5秒
# epoch：703/1000   loss_F： 3.6683   経過時間： 14.6秒
# epoch：704/1000   loss_F： 3.6719   経過時間： 14.6秒
# epoch：705/1000   loss_F： 3.6980   経過時間： 14.6秒
# epoch：706/1000   loss_F： 3.6648   経過時間： 14.6秒
# epoch：707/1000   loss_F： 3.6790   経過時間： 14.6秒
# epoch：708/1000   loss_F： 3.6595   経過時間： 14.7秒
# epoch：709/1000   loss_F： 3.6870   経過時間： 14.7秒
# epoch：710/1000   loss_F： 3.7454   経過時間： 14.7秒
# epoch：711/1000   loss_F： 3.6916   経過時間： 14.7秒
# epoch：712/1000   loss_F： 3.6725   経過時間： 14.7秒
# epoch：713/1000   loss_F： 3.7034   経過時間： 14.8秒
# epoch：714/1000   loss_F： 3.6448   経過時間： 14.8秒
# epoch：715/1000   loss_F： 3.6257   経過時間： 14.8秒
# epoch：716/1000   loss_F： 3.6019   経過時間： 14.8秒
# epoch：717/1000   loss_F： 3.6663   経過時間： 14.8秒
# epoch：718/1000   loss_F： 3.6362   経過時間： 14.9秒
# epoch：719/1000   loss_F： 3.7194   経過時間： 14.9秒
# epoch：720/1000   loss_F： 3.7642   経過時間： 14.9秒
# epoch：721/1000   loss_F： 3.6713   経過時間： 14.9秒
# epoch：722/1000   loss_F： 3.7392   経過時間： 15.0秒
# epoch：723/1000   loss_F： 3.6706   経過時間： 15.0秒
# epoch：724/1000   loss_F： 3.7207   経過時間： 15.0秒
# epoch：725/1000   loss_F： 3.6946   経過時間： 15.0秒
# epoch：726/1000   loss_F： 3.6746   経過時間： 15.1秒
# epoch：727/1000   loss_F： 3.7431   経過時間： 15.1秒
# epoch：728/1000   loss_F： 3.7338   経過時間： 15.1秒
# epoch：729/1000   loss_F： 3.7000   経過時間： 15.1秒
# epoch：730/1000   loss_F： 3.6755   経過時間： 15.1秒
# epoch：731/1000   loss_F： 3.6895   経過時間： 15.2秒
# epoch：732/1000   loss_F： 3.6745   経過時間： 15.2秒
# epoch：733/1000   loss_F： 3.6455   経過時間： 15.2秒
# epoch：734/1000   loss_F： 3.5857   経過時間： 15.2秒
# epoch：735/1000   loss_F： 3.6795   経過時間： 15.2秒
# epoch：736/1000   loss_F： 3.7444   経過時間： 15.3秒
# epoch：737/1000   loss_F： 3.6936   経過時間： 15.3秒
# epoch：738/1000   loss_F： 3.8001   経過時間： 15.3秒
# epoch：739/1000   loss_F： 3.7012   経過時間： 15.3秒
# epoch：740/1000   loss_F： 3.6356   経過時間： 15.4秒
# epoch：741/1000   loss_F： 3.6512   経過時間： 15.4秒
# epoch：742/1000   loss_F： 3.7285   経過時間： 15.4秒
# epoch：743/1000   loss_F： 3.6269   経過時間： 15.4秒
# epoch：744/1000   loss_F： 3.7227   経過時間： 15.4秒
# epoch：745/1000   loss_F： 3.7803   経過時間： 15.5秒
# epoch：746/1000   loss_F： 3.6599   経過時間： 15.5秒
# epoch：747/1000   loss_F： 3.7010   経過時間： 15.5秒
# epoch：748/1000   loss_F： 3.6288   経過時間： 15.5秒
# epoch：749/1000   loss_F： 3.7432   経過時間： 15.5秒
# epoch：750/1000   loss_F： 3.6382   経過時間： 15.6秒
# epoch：751/1000   loss_F： 3.7040   経過時間： 15.6秒
# epoch：752/1000   loss_F： 3.7199   経過時間： 15.6秒
# epoch：753/1000   loss_F： 3.6364   経過時間： 15.6秒
# epoch：754/1000   loss_F： 3.6713   経過時間： 15.7秒
# epoch：755/1000   loss_F： 3.6976   経過時間： 15.7秒
# epoch：756/1000   loss_F： 3.6563   経過時間： 15.7秒
# epoch：757/1000   loss_F： 3.5755   経過時間： 15.7秒
# epoch：758/1000   loss_F： 3.7118   経過時間： 15.7秒
# epoch：759/1000   loss_F： 3.6098   経過時間： 15.8秒
# epoch：760/1000   loss_F： 3.7372   経過時間： 15.8秒
# epoch：761/1000   loss_F： 3.6271   経過時間： 15.8秒
# epoch：762/1000   loss_F： 3.6784   経過時間： 15.8秒
# epoch：763/1000   loss_F： 3.7121   経過時間： 15.8秒
# epoch：764/1000   loss_F： 3.6664   経過時間： 15.9秒
# epoch：765/1000   loss_F： 3.7374   経過時間： 15.9秒
# epoch：766/1000   loss_F： 3.7124   経過時間： 15.9秒
# epoch：767/1000   loss_F： 3.7124   経過時間： 15.9秒
# epoch：768/1000   loss_F： 3.6480   経過時間： 15.9秒
# epoch：769/1000   loss_F： 3.6658   経過時間： 16.0秒
# epoch：770/1000   loss_F： 3.6776   経過時間： 16.0秒
# epoch：771/1000   loss_F： 3.6598   経過時間： 16.0秒
# epoch：772/1000   loss_F： 3.6695   経過時間： 16.0秒
# epoch：773/1000   loss_F： 3.6130   経過時間： 16.0秒
# epoch：774/1000   loss_F： 3.7177   経過時間： 16.1秒
# epoch：775/1000   loss_F： 3.6814   経過時間： 16.1秒
# epoch：776/1000   loss_F： 3.6831   経過時間： 16.1秒
# epoch：777/1000   loss_F： 3.6068   経過時間： 16.1秒
# epoch：778/1000   loss_F： 3.6832   経過時間： 16.1秒
# epoch：779/1000   loss_F： 3.7218   経過時間： 16.2秒
# epoch：780/1000   loss_F： 3.7053   経過時間： 16.2秒
# epoch：781/1000   loss_F： 3.7828   経過時間： 16.2秒
# epoch：782/1000   loss_F： 3.6938   経過時間： 16.2秒
# epoch：783/1000   loss_F： 3.7245   経過時間： 16.2秒
# epoch：784/1000   loss_F： 3.6168   経過時間： 16.3秒
# epoch：785/1000   loss_F： 3.6998   経過時間： 16.3秒
# epoch：786/1000   loss_F： 3.6901   経過時間： 16.3秒
# epoch：787/1000   loss_F： 3.6465   経過時間： 16.3秒
# epoch：788/1000   loss_F： 3.7437   経過時間： 16.3秒
# epoch：789/1000   loss_F： 3.7253   経過時間： 16.4秒
# epoch：790/1000   loss_F： 3.6261   経過時間： 16.4秒
# epoch：791/1000   loss_F： 3.6878   経過時間： 16.4秒
# epoch：792/1000   loss_F： 3.5939   経過時間： 16.4秒
# epoch：793/1000   loss_F： 3.6468   経過時間： 16.4秒
# epoch：794/1000   loss_F： 3.7292   経過時間： 16.5秒
# epoch：795/1000   loss_F： 3.6683   経過時間： 16.5秒
# epoch：796/1000   loss_F： 3.6562   経過時間： 16.5秒
# epoch：797/1000   loss_F： 3.7268   経過時間： 16.5秒
# epoch：798/1000   loss_F： 3.6895   経過時間： 16.5秒
# epoch：799/1000   loss_F： 3.6796   経過時間： 16.6秒
# epoch：800/1000   loss_F： 3.6833   経過時間： 16.6秒
# epoch：801/1000   loss_F： 3.7045   経過時間： 16.6秒
# epoch：802/1000   loss_F： 3.7571   経過時間： 16.6秒
# epoch：803/1000   loss_F： 3.7911   経過時間： 16.6秒
# epoch：804/1000   loss_F： 3.7286   経過時間： 16.7秒
# epoch：805/1000   loss_F： 3.6505   経過時間： 16.7秒
# epoch：806/1000   loss_F： 3.7172   経過時間： 16.7秒
# epoch：807/1000   loss_F： 3.7176   経過時間： 16.7秒
# epoch：808/1000   loss_F： 3.7171   経過時間： 16.8秒
# epoch：809/1000   loss_F： 3.6659   経過時間： 16.8秒
# epoch：810/1000   loss_F： 3.6769   経過時間： 16.8秒
# epoch：811/1000   loss_F： 3.7538   経過時間： 16.8秒
# epoch：812/1000   loss_F： 3.6615   経過時間： 16.9秒
# epoch：813/1000   loss_F： 3.7756   経過時間： 16.9秒
# epoch：814/1000   loss_F： 3.6388   経過時間： 16.9秒
# epoch：815/1000   loss_F： 3.6382   経過時間： 16.9秒
# epoch：816/1000   loss_F： 3.6471   経過時間： 16.9秒
# epoch：817/1000   loss_F： 3.7000   経過時間： 17.0秒
# epoch：818/1000   loss_F： 3.6204   経過時間： 17.0秒
# epoch：819/1000   loss_F： 3.8105   経過時間： 17.0秒
# epoch：820/1000   loss_F： 3.6587   経過時間： 17.0秒
# epoch：821/1000   loss_F： 3.6288   経過時間： 17.1秒
# epoch：822/1000   loss_F： 3.6831   経過時間： 17.1秒
# epoch：823/1000   loss_F： 3.6618   経過時間： 17.1秒
# epoch：824/1000   loss_F： 3.6597   経過時間： 17.1秒
# epoch：825/1000   loss_F： 3.6606   経過時間： 17.2秒
# epoch：826/1000   loss_F： 3.6931   経過時間： 17.2秒
# epoch：827/1000   loss_F： 3.7244   経過時間： 17.2秒
# epoch：828/1000   loss_F： 3.5787   経過時間： 17.2秒
# epoch：829/1000   loss_F： 3.6609   経過時間： 17.2秒
# epoch：830/1000   loss_F： 3.6326   経過時間： 17.3秒
# epoch：831/1000   loss_F： 3.6306   経過時間： 17.3秒
# epoch：832/1000   loss_F： 3.7133   経過時間： 17.3秒
# epoch：833/1000   loss_F： 3.6388   経過時間： 17.3秒
# epoch：834/1000   loss_F： 3.6966   経過時間： 17.3秒
# epoch：835/1000   loss_F： 3.6974   経過時間： 17.4秒
# epoch：836/1000   loss_F： 3.7330   経過時間： 17.4秒
# epoch：837/1000   loss_F： 3.8010   経過時間： 17.4秒
# epoch：838/1000   loss_F： 3.5993   経過時間： 17.4秒
# epoch：839/1000   loss_F： 3.5906   経過時間： 17.4秒
# epoch：840/1000   loss_F： 3.6730   経過時間： 17.5秒
# epoch：841/1000   loss_F： 3.7254   経過時間： 17.5秒
# epoch：842/1000   loss_F： 3.6468   経過時間： 17.5秒
# epoch：843/1000   loss_F： 3.7020   経過時間： 17.5秒
# epoch：844/1000   loss_F： 3.6566   経過時間： 17.5秒
# epoch：845/1000   loss_F： 3.7828   経過時間： 17.6秒
# epoch：846/1000   loss_F： 3.6809   経過時間： 17.6秒
# epoch：847/1000   loss_F： 3.7202   経過時間： 17.6秒
# epoch：848/1000   loss_F： 3.7145   経過時間： 17.6秒
# epoch：849/1000   loss_F： 3.7460   経過時間： 17.6秒
# epoch：850/1000   loss_F： 3.6577   経過時間： 17.7秒
# epoch：851/1000   loss_F： 3.6906   経過時間： 17.7秒
# epoch：852/1000   loss_F： 3.7775   経過時間： 17.7秒
# epoch：853/1000   loss_F： 3.7584   経過時間： 17.7秒
# epoch：854/1000   loss_F： 3.7142   経過時間： 17.8秒
# epoch：855/1000   loss_F： 3.7664   経過時間： 17.8秒
# epoch：856/1000   loss_F： 3.7708   経過時間： 17.8秒
# epoch：857/1000   loss_F： 3.6665   経過時間： 17.8秒
# epoch：858/1000   loss_F： 3.6730   経過時間： 17.8秒
# epoch：859/1000   loss_F： 3.6790   経過時間： 17.9秒
# epoch：860/1000   loss_F： 3.6379   経過時間： 17.9秒
# epoch：861/1000   loss_F： 3.6069   経過時間： 17.9秒
# epoch：862/1000   loss_F： 3.6940   経過時間： 17.9秒
# epoch：863/1000   loss_F： 3.6827   経過時間： 17.9秒
# epoch：864/1000   loss_F： 3.7148   経過時間： 18.0秒
# epoch：865/1000   loss_F： 3.6789   経過時間： 18.0秒
# epoch：866/1000   loss_F： 3.6795   経過時間： 18.0秒
# epoch：867/1000   loss_F： 3.6216   経過時間： 18.0秒
# epoch：868/1000   loss_F： 3.7383   経過時間： 18.0秒
# epoch：869/1000   loss_F： 3.6624   経過時間： 18.1秒
# epoch：870/1000   loss_F： 3.7061   経過時間： 18.1秒
# epoch：871/1000   loss_F： 3.7065   経過時間： 18.1秒
# epoch：872/1000   loss_F： 3.7684   経過時間： 18.1秒
# epoch：873/1000   loss_F： 3.7079   経過時間： 18.1秒
# epoch：874/1000   loss_F： 3.5807   経過時間： 18.2秒
# epoch：875/1000   loss_F： 3.7923   経過時間： 18.2秒
# epoch：876/1000   loss_F： 3.6751   経過時間： 18.2秒
# epoch：877/1000   loss_F： 3.5962   経過時間： 18.2秒
# epoch：878/1000   loss_F： 3.6768   経過時間： 18.2秒
# epoch：879/1000   loss_F： 3.7634   経過時間： 18.3秒
# epoch：880/1000   loss_F： 3.7034   経過時間： 18.3秒
# epoch：881/1000   loss_F： 3.7144   経過時間： 18.3秒
# epoch：882/1000   loss_F： 3.7429   経過時間： 18.3秒
# epoch：883/1000   loss_F： 3.6886   経過時間： 18.3秒
# epoch：884/1000   loss_F： 3.5675   経過時間： 18.4秒
# epoch：885/1000   loss_F： 3.7018   経過時間： 18.4秒
# epoch：886/1000   loss_F： 3.6412   経過時間： 18.4秒
# epoch：887/1000   loss_F： 3.7270   経過時間： 18.4秒
# epoch：888/1000   loss_F： 3.6772   経過時間： 18.4秒
# epoch：889/1000   loss_F： 3.6994   経過時間： 18.5秒
# epoch：890/1000   loss_F： 3.5777   経過時間： 18.5秒
# epoch：891/1000   loss_F： 3.7331   経過時間： 18.5秒
# epoch：892/1000   loss_F： 3.6915   経過時間： 18.5秒
# epoch：893/1000   loss_F： 3.7302   経過時間： 18.5秒
# epoch：894/1000   loss_F： 3.6431   経過時間： 18.6秒
# epoch：895/1000   loss_F： 3.6668   経過時間： 18.6秒
# epoch：896/1000   loss_F： 3.7018   経過時間： 18.6秒
# epoch：897/1000   loss_F： 3.5848   経過時間： 18.6秒
# epoch：898/1000   loss_F： 3.6845   経過時間： 18.6秒
# epoch：899/1000   loss_F： 3.6889   経過時間： 18.7秒
# epoch：900/1000   loss_F： 3.6656   経過時間： 18.7秒
# epoch：901/1000   loss_F： 3.5698   経過時間： 18.7秒
# epoch：902/1000   loss_F： 3.6972   経過時間： 18.7秒
# epoch：903/1000   loss_F： 3.7121   経過時間： 18.7秒
# epoch：904/1000   loss_F： 3.6629   経過時間： 18.8秒
# epoch：905/1000   loss_F： 3.7042   経過時間： 18.8秒
# epoch：906/1000   loss_F： 3.7731   経過時間： 18.8秒
# epoch：907/1000   loss_F： 3.7424   経過時間： 18.8秒
# epoch：908/1000   loss_F： 3.6568   経過時間： 18.9秒
# epoch：909/1000   loss_F： 3.7392   経過時間： 18.9秒
# epoch：910/1000   loss_F： 3.6415   経過時間： 18.9秒
# epoch：911/1000   loss_F： 3.6730   経過時間： 18.9秒
# epoch：912/1000   loss_F： 3.6522   経過時間： 18.9秒
# epoch：913/1000   loss_F： 3.6565   経過時間： 19.0秒
# epoch：914/1000   loss_F： 3.6366   経過時間： 19.0秒
# epoch：915/1000   loss_F： 3.6164   経過時間： 19.0秒
# epoch：916/1000   loss_F： 3.6599   経過時間： 19.0秒
# epoch：917/1000   loss_F： 3.6329   経過時間： 19.0秒
# epoch：918/1000   loss_F： 3.6437   経過時間： 19.1秒
# epoch：919/1000   loss_F： 3.5105   経過時間： 19.1秒
# epoch：920/1000   loss_F： 3.7332   経過時間： 19.1秒
# epoch：921/1000   loss_F： 3.6231   経過時間： 19.1秒
# epoch：922/1000   loss_F： 3.5938   経過時間： 19.2秒
# epoch：923/1000   loss_F： 3.6553   経過時間： 19.2秒
# epoch：924/1000   loss_F： 3.7308   経過時間： 19.2秒
# epoch：925/1000   loss_F： 3.5492   経過時間： 19.2秒
# epoch：926/1000   loss_F： 3.7170   経過時間： 19.2秒
# epoch：927/1000   loss_F： 3.6550   経過時間： 19.3秒
# epoch：928/1000   loss_F： 3.7440   経過時間： 19.3秒
# epoch：929/1000   loss_F： 3.7046   経過時間： 19.3秒
# epoch：930/1000   loss_F： 3.6558   経過時間： 19.3秒
# epoch：931/1000   loss_F： 3.7002   経過時間： 19.3秒
# epoch：932/1000   loss_F： 3.7070   経過時間： 19.4秒
# epoch：933/1000   loss_F： 3.6749   経過時間： 19.4秒
# epoch：934/1000   loss_F： 3.6924   経過時間： 19.4秒
# epoch：935/1000   loss_F： 3.6455   経過時間： 19.4秒
# epoch：936/1000   loss_F： 3.7644   経過時間： 19.4秒
# epoch：937/1000   loss_F： 3.8151   経過時間： 19.5秒
# epoch：938/1000   loss_F： 3.6319   経過時間： 19.5秒
# epoch：939/1000   loss_F： 3.6982   経過時間： 19.5秒
# epoch：940/1000   loss_F： 3.6557   経過時間： 19.5秒
# epoch：941/1000   loss_F： 3.5807   経過時間： 19.5秒
# epoch：942/1000   loss_F： 3.6652   経過時間： 19.6秒
# epoch：943/1000   loss_F： 3.7151   経過時間： 19.6秒
# epoch：944/1000   loss_F： 3.6195   経過時間： 19.6秒
# epoch：945/1000   loss_F： 3.5930   経過時間： 19.6秒
# epoch：946/1000   loss_F： 3.7320   経過時間： 19.6秒
# epoch：947/1000   loss_F： 3.6462   経過時間： 19.7秒
# epoch：948/1000   loss_F： 3.6123   経過時間： 19.7秒
# epoch：949/1000   loss_F： 3.6414   経過時間： 19.7秒
# epoch：950/1000   loss_F： 3.7374   経過時間： 19.7秒
# epoch：951/1000   loss_F： 3.7344   経過時間： 19.7秒
# epoch：952/1000   loss_F： 3.7985   経過時間： 19.8秒
# epoch：953/1000   loss_F： 3.6779   経過時間： 19.8秒
# epoch：954/1000   loss_F： 3.6268   経過時間： 19.8秒
# epoch：955/1000   loss_F： 3.6504   経過時間： 19.8秒
# epoch：956/1000   loss_F： 3.6801   経過時間： 19.8秒
# epoch：957/1000   loss_F： 3.6981   経過時間： 19.9秒
# epoch：958/1000   loss_F： 3.6430   経過時間： 19.9秒
# epoch：959/1000   loss_F： 3.6828   経過時間： 19.9秒
# epoch：960/1000   loss_F： 3.6678   経過時間： 19.9秒
# epoch：961/1000   loss_F： 3.6264   経過時間： 19.9秒
# epoch：962/1000   loss_F： 3.6842   経過時間： 20.0秒
# epoch：963/1000   loss_F： 3.6642   経過時間： 20.0秒
# epoch：964/1000   loss_F： 3.6741   経過時間： 20.0秒
# epoch：965/1000   loss_F： 3.6634   経過時間： 20.0秒
# epoch：966/1000   loss_F： 3.5879   経過時間： 20.0秒
# epoch：967/1000   loss_F： 3.7010   経過時間： 20.1秒
# epoch：968/1000   loss_F： 3.7567   経過時間： 20.1秒
# epoch：969/1000   loss_F： 3.7044   経過時間： 20.1秒
# epoch：970/1000   loss_F： 3.6379   経過時間： 20.1秒
# epoch：971/1000   loss_F： 3.5983   経過時間： 20.1秒
# epoch：972/1000   loss_F： 3.6713   経過時間： 20.2秒
# epoch：973/1000   loss_F： 3.6533   経過時間： 20.2秒
# epoch：974/1000   loss_F： 3.7091   経過時間： 20.2秒
# epoch：975/1000   loss_F： 3.7031   経過時間： 20.2秒
# epoch：976/1000   loss_F： 3.6746   経過時間： 20.2秒
# epoch：977/1000   loss_F： 3.7633   経過時間： 20.3秒
# epoch：978/1000   loss_F： 3.7509   経過時間： 20.3秒
# epoch：979/1000   loss_F： 3.6550   経過時間： 20.3秒
# epoch：980/1000   loss_F： 3.6648   経過時間： 20.3秒
# epoch：981/1000   loss_F： 3.7585   経過時間： 20.3秒
# epoch：982/1000   loss_F： 3.5972   経過時間： 20.4秒
# epoch：983/1000   loss_F： 3.7530   経過時間： 20.4秒
# epoch：984/1000   loss_F： 3.7245   経過時間： 20.4秒
# epoch：985/1000   loss_F： 3.6888   経過時間： 20.4秒
# epoch：986/1000   loss_F： 3.6676   経過時間： 20.5秒
# epoch：987/1000   loss_F： 3.6283   経過時間： 20.5秒
# epoch：988/1000   loss_F： 3.7970   経過時間： 20.5秒
# epoch：989/1000   loss_F： 3.6418   経過時間： 20.5秒
# epoch：990/1000   loss_F： 3.7149   経過時間： 20.5秒
# epoch：991/1000   loss_F： 3.7055   経過時間： 20.6秒
# epoch：992/1000   loss_F： 3.6658   経過時間： 20.6秒
# epoch：993/1000   loss_F： 3.6667   経過時間： 20.6秒
# epoch：994/1000   loss_F： 3.6384   経過時間： 20.6秒
# epoch：995/1000   loss_F： 3.6213   経過時間： 20.6秒
# epoch：996/1000   loss_F： 3.6492   経過時間： 20.6秒
# epoch：997/1000   loss_F： 3.6846   経過時間： 20.7秒
# epoch：998/1000   loss_F： 3.6019   経過時間： 20.7秒
# epoch：999/1000   loss_F： 3.7713   経過時間： 20.7秒
# epoch：1000/1000   loss_F： 3.6440   経過時間： 20.7秒

# %% [markdown]
# ### 学習できてるのか確かめる

# %% [markdown]
# #### 学習前のpredictorと学習後のpredictorのtestLossを比較する

# %%
testData = tsModel.ARIMA(a=phi_a, b=phi_b, N=1000, random_seed=2**32-1, randomness='normal')
testdataset = DataSet(testData, hat_p=hat_p)
testdataloader = torch.utils.data.DataLoader(testdataset, batch_size=opt.batch_size, shuffle=True, drop_last=True)

# %%
torch.manual_seed(opt.predictor_seed)
predictor = predictNet(p=hat_p)

pred = []
for i in range(1000):
    if i < 6:
        pred.append(0)
    else:
        ret = torch.cat([torch.zeros(1,1), torch.tensor(testData[i-hat_p:i], dtype=torch.float).view(1,-1)], axis = 1)
        ret = predictor(ret)
        pred.append(ret.item())
    
plt.figure(figsize=(13,8))
plt.plot(pred, label="学習前")
plt.plot(testData, label = "正解")

predictor.load_state_dict(torch.load(pretrain_param)) 
pred = []
for i in range(1000):
    if i < 6:
        pred.append(0)
    else:
        ret = torch.cat([torch.zeros(1,1), torch.tensor(testData[i-hat_p:i], dtype=torch.float).view(1,-1)], axis = 1)
        ret = predictor(ret)
        pred.append(ret.item())
plt.plot(pred, label="学習後")
plt.legend()

# %% [markdown]
# 学習してない

# %% [markdown]
# #### 偶数と奇数を当てる問題で、コードのミスかどうかを調べる
